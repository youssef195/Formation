# %%
import warnings
from warnings import filterwarnings

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-32229617-d06a-48d8-baac-ab558d36f113" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32229617-d06a-48d8-baac-ab558d36f113">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_v1.0.csv to data_v1.0.csv
# {'data_v1.0.csv': b',index,date,cheveux,age,exp,salaire,sexe,diplome,specialite,note,dispo,embauche\r\n0,0,2012-06-02,roux,25.0,9.0,26803.0,F,licence,geologie,97.08,non,0\r\n1,1,2011-04-21,blond,35.0,13.0,38166.0,M,licence,forage,63.86,non,0\r\n2,2,2012-09-07,blond,29.0,13.0,35207.0,M,licence,geologie,78.5,non,0\r\n3,3,2011-07-01,brun,,12.0,32442.0,M,licence,geologie,45.09,non,0\r\n4,4,2012-08-07,roux,35.0,6.0,28533.0,F,licence,detective,81.91,non,0\r\n5,5,2014-02-12,chatain,37.0,8.0,38558.0,M,master,geologie,63.46,non,1\r\n6,6,2013-11-11,brun,33.0,12.0,39476.0,M,master,geologie,50.2,oui,0\r\n7,7,2012-03-10,roux,31.0,10.0,42392.0,M,licence,forage,62.2,oui,0\r\n8,8,2014-10-17,chatain,43.0,10.0,28625.0,M,doctorat,geologie,65.17,non,1\r\n9,9,2011-06-04,chatain,28.0,11.0,32454.0,M,master,forage,66.93,non,1\r\n10,10,2014-08-06,brun,50.0,12.0,38516.0,F,licence,geologie,58.93,non,0\r\n11,11,2010-04-22,blond,43.0,8.0,38719.0,M,master,archeologie,80.07,oui,0\r\n12,12,2011-10-23,brun,44.0,9.0,28688.0,M,doctorat,forage,115.76,oui,0\r\n13,13,2014-06-25,brun,39.0,4.0,30822.0,F,licence,geologie,66.85,non,0\r\n14,14,2011-10-15,roux,23.0,14.0,33882.0,M,licence,geologie,61.46,non,0\r\n15,15,2010-07-12,brun,38.0,3.0,40889.0,M,master,geologie,62.85,oui,0\r\n16,16,2012-02-05,brun,31.0,10.0,28507.0,M,doctorat,forage,104.26,oui,0\r\n17,17,2010-07-03,blond,37.0,13.0,41512.0,M,bac,geologie,55.91,non,0\r\n18,18,2010-07-21,blond,35.0,14.0,30359.0,M,licence,geologie,94.58,non,0\r\n19,19,2014-07-22,chatain,44.0,8.0,28956.0,M,master,geologie,74.82,non,0\r\n20,20,2010-02-12,brun,31.0,12.0,34483.0,M,master,forage,66.27,oui,0\r\n21,21,2014-05-22,chatain,30.0,10.0,39069.0,F,licence,forage,65.19,non,0\r\n22,22,2010-01-04,brun,39.0,13.0,34632.0,M,master,geologie,81.35,non,0\r\n23,23,2012-03-20,brun,31.0,8.0,41582.0,M,licence,geologie,58.94,non,0\r\n24,24,2012-01-
# %%
import pandas as pd
import numpy as np

df=pd.read_csv("data_v1.0.csv", parse_dates=["date"])
df.dtypes
df.shape
df.head()

df.pop("Unnamed: 0")
df.head()
# Out:
#    index       date cheveux   age   exp  salaire sexe  diplome specialite  \
# 0      0 2012-06-02    roux  25.0   9.0  26803.0    F  licence   geologie
# 1      1 2011-04-21   blond  35.0  13.0  38166.0    M  licence     forage
# 2      2 2012-09-07   blond  29.0  13.0  35207.0    M  licence   geologie
# 3      3 2011-07-01    brun   NaN  12.0  32442.0    M  licence   geologie
# 4      4 2012-08-07    roux  35.0   6.0  28533.0    F  licence  detective
#
#     note dispo  embauche
# 0  97.08   non         0
# 1  63.86   non         0
# 2  78.50   non         0
# 3  45.09   non         0
# 4  81.91   non         0

# %%
df.duplicated().sum()
df.isna().any().any()
# Out:
# True

# %% [markdown]
# for col in df.columns:
#   pct_missing=np.mean(df[col].isnull())
#   print('{} - {}% - {}'.format(col, round(pct_missing*100,1),np.sum(df[col].isnull())))

# %%
ndf=df.drop(["embauche"],axis=1)
ndf=ndf.dropna(axis=0,how="all")
ndf
# Out:
#        index       date  cheveux   age   exp  salaire sexe   diplome  \
# 0          0 2012-06-02     roux  25.0   9.0  26803.0    F   licence
# 1          1 2011-04-21    blond  35.0  13.0  38166.0    M   licence
# 2          2 2012-09-07    blond  29.0  13.0  35207.0    M   licence
# 3          3 2011-07-01     brun   NaN  12.0  32442.0    M   licence
# 4          4 2012-08-07     roux  35.0   6.0  28533.0    F   licence
# ...      ...        ...      ...   ...   ...      ...  ...       ...
# 19995  19995 2012-03-10     roux  47.0   9.0  35723.0    M   licence
# 19996  19996 2010-09-19  chatain  38.0  10.0  33570.0    F    master
# 19997  19997 2010-09-02  chatain  23.0   6.0  33751.0    F  doctorat
# 19998  19998 2011-12-06  chatain  33.0  11.0  34167.0    F   licence
# 19999  19999 2010-11-29     brun  35.0  14.0  44499.0    M       bac
#
#       specialite    note dispo
# 0       geologie   97.08   non
# 1         forage   63.86   non
# 2       geologie   78.50   non
# 3       geologie   45.09   non
# 4      detective   81.91   non
# ...          ...     ...   ...
# 19995   geologie   66.47   non
# 19996   geologie   62.29   non
# 19997  detective  103.48   oui
# 19998  detective   73.35   non
# 19999   geologie   45.62   non
#
# [20000 rows x 11 columns]

# %%
missing_df = df[df.isnull().any(axis = 1)]
fdf=df.dropna()

# %%
from collections import Counter
